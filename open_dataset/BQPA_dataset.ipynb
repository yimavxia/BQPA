# %%
# some constants
pi=3.141592657

bluethis='#009ADE'
redthis='#FF1F5B'
greenthis='#00CD6C'
purplethis='#AF58BA'

import json
import numpy as np

# %% [markdown]
# # Thermal conductivity analysis

# %%
# MgO
data_tmp = np.loadtxt("kappa_mgo_3ph_qpa.dat")
x1 = data_tmp[:,0]
y1 = data_tmp[:,1] + data_tmp[:,2]
data_tmp = np.loadtxt("kappa_mgo_3ph_bqpa.dat")
x2 = data_tmp[:,0]
y2 = data_tmp[:,1] + data_tmp[:,2]
data_tmp = np.loadtxt("kappa_mgo_4ph_qpa.dat")
x3 = data_tmp[:,0]
y3 = data_tmp[:,1] + data_tmp[:,2]
data_tmp = np.loadtxt("kappa_mgo_4ph_bqpa.dat")
x4 = data_tmp[:,0]
y4 = data_tmp[:,1] + data_tmp[:,2]

# PbTe
data_tmp = np.loadtxt("kappa_pbte_3ph_qpa.dat")
x5 = data_tmp[:,0]
y5 = data_tmp[:,1] + data_tmp[:,2]
data_tmp = np.loadtxt("kappa_pbte_3ph_bqpa.dat")
x6 = data_tmp[:,0]
y6 = data_tmp[:,1] + data_tmp[:,2]
data_tmp = np.loadtxt("kappa_pbte_4ph_qpa.dat")
x7 = data_tmp[:,0]
y7 = data_tmp[:,1] + data_tmp[:,2]
data_tmp = np.loadtxt("kappa_pbte_4ph_bqpa.dat")
x8 = data_tmp[:,0]
y8 = data_tmp[:,1] + data_tmp[:,2]

# AgCl
data_tmp = np.loadtxt("kappa_agcl_3ph_qpa.dat")
x9 = data_tmp[:,0]
y9 = data_tmp[:,1] + data_tmp[:,2]
data_tmp = np.loadtxt("kappa_agcl_3ph_bqpa.dat")
x10 = data_tmp[:,0]
y10 = data_tmp[:,1] + data_tmp[:,2]
data_tmp = np.loadtxt("kappa_agcl_4ph_qpa.dat")
x11 = data_tmp[:,0]
y11 = data_tmp[:,1] + data_tmp[:,2]
data_tmp = np.loadtxt("kappa_agcl_4ph_bqpa.dat")
x12 = data_tmp[:,0]
y12 = data_tmp[:,1] + data_tmp[:,2]

import matplotlib.pyplot as plt
import pandas as pd

bluethis='#009ADE'
redthis='#FF1F5B'
greenthis='#00CD6C'
purplethis='#AF58BA'
redthis = '#d63f27'
bluethis = '#3cb3d8' 
greenthis = '#008878'
purplethis = '#8e44ad'
sizemarker = 10
plt.figure(figsize=(6, 4)) 
# MgO
plt.plot(x1, y1, marker='d', linestyle='--', linewidth=0.5, color=purplethis, label='3ph-QPA', markersize=sizemarker/1.5)
plt.plot(x2, y2, marker='v', linestyle='--', linewidth=0.5, color=bluethis, label='3ph-BQPA', markersize=sizemarker/1.5)
plt.plot(x3, y3, marker='s', linestyle='--', linewidth=0.5, color=greenthis, label='3,4ph-QPA', markersize=sizemarker/1.5)
plt.plot(x4, y4, marker='o', linestyle='--', linewidth=0.5, color=redthis, label='3,4ph-BQPA', markersize=sizemarker/1.5)
# PbTe
plt.plot(x5, y5, marker='d', linestyle='--', linewidth=0.5, color=purplethis, markersize=sizemarker/1.5)
plt.plot(x6, y6, marker='v', linestyle='--', linewidth=0.5, color=bluethis, markersize=sizemarker/1.5)
plt.plot(x7, y7, marker='s', linestyle='--', linewidth=0.5, color=greenthis, markersize=sizemarker/1.5)
plt.plot(x8, y8, marker='o', linestyle='--', linewidth=0.5, color=redthis, markersize=sizemarker/1.5)
# AgCl
plt.plot(x9, y9, marker='d', linestyle='--', linewidth=0.5, color=purplethis, markersize=sizemarker/1.5)
plt.plot(x10, y10, marker='v', linestyle='--', linewidth=0.5, color=bluethis, markersize=sizemarker/1.5)
plt.plot(x11, y11, marker='s', linestyle='--', linewidth=0.5, color=greenthis, markersize=sizemarker/1.5)
plt.plot(x12, y12, marker='o', linestyle='--', linewidth=0.5, color=redthis, markersize=sizemarker/1.5)


#Touloukian YS, Powell RW, HC Y, KP G (1970) Thermophysical Properties of Matter—
#The TPRC Data Series. Thermal Conductivity—Nonmetallic Solids (IFI/Plenum, New York) p 166.
df = pd.read_csv('data_kappa_mgo_1.csv')
x_mgo_1 = df.iloc[:,0].tolist()
y_mgo_1 = df.iloc[:,1].tolist()

# Slack GA (1962) Thermal conductivity of MgO, Al2 O3 , MgAl2 O4 , and Fe3 O4 crystals from 3 K to 300 K. Phys Rev 126:427–441.
df = pd.read_csv('data_kappa_mgo_2.csv')
x_mgo_2 = df.iloc[:,0].tolist()
y_mgo_2 = df.iloc[:,1].tolist()

# A. M. Hofmeister, Thermal diffusivity and thermal conductivity of single-crystal MgO and Al2O3 
#and related compounds as a function of temperature, Phys. Chem. Miner. 41, 361 (2014).
df = pd.read_csv('data_kappa_mgo_3.csv')
x_mgo_3 = df.iloc[:,0].tolist()
y_mgo_3 = df.iloc[:,1].tolist()

# D. G. Cahill, S.-M. Lee, and T. I. Selinder, Thermal conductivity of κ-Al2O3 and α-Al2O3 wear-resistant 
#coatings, J. Appl. Phys. 83, 5783 (1998).
df = pd.read_csv('data_kappa_mgo_4.csv')
x_mgo_4 = df.iloc[:,0].tolist()
y_mgo_4 = df.iloc[:,1].tolist()

#International Journal of Thermophysics, Vol. 4, No. 3, 1983
df = pd.read_csv('data_kappa_pbte.csv')
x_pbte_1 = df.iloc[:,0].tolist()
y_pbte_1 = df.iloc[:,1].tolist()

#International Journal of Thermophysics, Vol. 4, No. 3, 1983
df = pd.read_csv('data_kappa_agcl_1.csv')
x_agcl_1 = df.iloc[:,0].tolist()
y_agcl_1 = df.iloc[:,1].tolist()

df = pd.read_csv('data_kappa_agcl_1.csv')
x_agcl_2 = df.iloc[:,0].tolist()
y_agcl_2 = df.iloc[:,1].tolist()

# Thermophysical properties of AgCl in the temperature range 77–300 K To cite this article: Asghari Maqsood et al 2004 J. Phys. D: Appl. Phys. 37 1845
# for data_kappa_agcl_1.csv



# Mgo exp
sizethis = 10
plt.xscale('log')
plt.yscale('log')
plt.xlim(100, 1700)
plt.ylim(5*10**-1, 10**2)

# MgO
#plt.plot(x_mgo_1, y_mgo_1, marker='D', linestyle='none', linewidth=0.5, color='black', markersize=sizethis, markerfacecolor='none', alpha=0.6)
plt.plot(x_mgo_4, y_mgo_4, marker='^', linestyle='none', linewidth=0.5, color='black', markersize=sizethis, markerfacecolor='none', alpha=0.6)
plt.plot(x_mgo_3, y_mgo_3, marker='p', linestyle='none', linewidth=0.5, color='black', markersize=sizethis, markerfacecolor='none', alpha=0.6)
# PbTe
plt.plot(x_pbte_1, y_pbte_1, marker='d', linestyle='none', linewidth=0.5, color='black', markersize=sizethis, markerfacecolor='none', alpha=0.6)
# AgCl
plt.plot(x_agcl_1, y_agcl_1, marker='s', linestyle='none', linewidth=0.5, color='black', markersize=sizethis, markerfacecolor='none', alpha=0.6)
#plt.plot(x_agcl_2, y_agcl_2, marker='o', linestyle='none', linewidth=0.5, color='black', markersize=sizethis, markerfacecolor='none', alpha=0.6)

plt.legend(fontsize=14, bbox_to_anchor=(0.425, 0.4))
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.size'] = 20
plt.rcParams['text.usetex'] = True
plt.rcParams['text.latex.preamble'] = r"\usepackage{mathptmx}"
plt.xlabel('Temperature (K)',fontname='Times New Roman',fontsize=20)
plt.ylabel(r'$\kappa_{\rm L}$ (W/m/K)',fontname='Times New Roman',fontsize=20)

plt.savefig("man_kappa_all.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %% [markdown]
# # Thermal conductivity at 300 K analysis

# %%
# thermal conductivity
# 3ph_qpa, 3ph_bqpa, 34ph_bqpa, 34ph_bqpa

# AgCl
# "/Users/yixia/Documents/Projects_nsf/nsf_bqpa/Ana-AgCl/spectrum-300-mesh25"
kappa_agcl_d = [1.06, 1.64, 0.89, 0.83]
kappa_agcl_od = [0.22, 0.35, 0.23, 0.20]

# PbTe
# "/Users/yixia/Documents/Projects_nsf/nsf_bqpa/Ana-PbTe/spectrum-300-sampling-mesh24"
kappa_pbte_d = [2.59, 2.76, 2.05, 2.03]
kappa_pbte_od = [0.06, 0.06, 0.06, 0.07]

# MgO
# "/Users/yixia/Documents/Projects_nsf/nsf_bqpa/Ana-MgO/spectrum-300/"
# no renormalization
kappa_mgo_d = [56.11, 57.08, 48.22, 48.05]
kappa_mgo_od = [0.33, 0.34, 0.35, 0.36]
# with renormalization
kappa_mgo_d = [65.66, 66.52, 56.10, 55.92]
kappa_mgo_od = [0.31, 0.32, 0.31, 0.32]

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# Data for stacked bar chart
categories = ['3ph-QPA', '3ph-BQPA', '3,4ph-QPA', '3,4ph-BQPA']
bottom_values = kappa_agcl_d
top_values = kappa_agcl_od  # Difference to make the total height match the plot

# Colors for each bar (bottom and top)
bottom_colors = ['#d63f27', '#3cb3d8', '#008878', '#8e44ad']  # Added purple
top_colors = ['#f29c9c', '#9ee1f3', '#7ac1ac', '#d2b4de']     # Lighter purple

# Plotting
fig, ax = plt.subplots(figsize=(6, 4.5))  # width x height in inches

# Plot bars
for i in range(len(categories)):
    ax.bar(categories[i], bottom_values[i], color=bottom_colors[i], width=0.6)
    ax.bar(categories[i], top_values[i], bottom=bottom_values[i], color=top_colors[i], width=0.6)

ax.axhline(y=1.0, color='grey', linestyle='--', linewidth=1)
ax.text(len(categories)-1.25, 1.13, 'Exp.', fontsize=20, va='bottom', ha='right', color='grey')
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.size'] = 20
plt.text(1.75, 2, 'AgCl @ 300K', fontsize=20)

# Y-axis label
ax.set_ylabel(r'$\kappa_{\rm L}$ (W/m/K)',fontsize=20)

# Y-axis limit
ax.set_ylim(0, 2.5)
#plt.xticks(rotation=20)
ax.set_xticks(range(len(categories)))
ax.set_xticklabels(categories, rotation=20, fontsize=19)

# Display plot
plt.tight_layout()
plt.savefig('man_agcl_kappa.pdf', format='pdf',bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# Data for stacked bar chart
categories = ['3ph-QPA', '3ph-BQPA', '3,4ph-QPA', '3,4ph-BQPA']
bottom_values = kappa_pbte_d
top_values = kappa_pbte_od  # Difference to make the total height match the plot

# Colors for each bar (bottom and top)
bottom_colors = ['#d63f27', '#3cb3d8', '#008878', '#8e44ad']  # Added purple
top_colors = ['#f29c9c', '#9ee1f3', '#7ac1ac', '#d2b4de']     # Lighter purple

# Plotting
fig, ax = plt.subplots(figsize=(6, 4.5))  # width x height in inches

# Plot bars
for i in range(len(categories)):
    ax.bar(categories[i], bottom_values[i], color=bottom_colors[i], width=0.6)
    ax.bar(categories[i], top_values[i], bottom=bottom_values[i], color=top_colors[i], width=0.6)

ax.axhline(y=2.1, color='grey', linestyle='--', linewidth=1)
ax.text(len(categories)-1.25, 2.13, 'Exp.', fontsize=20, va='bottom', ha='right', color='grey')
plt.text(1.75, 2.5, 'PbTe @ 300K', fontsize=20)

# Y-axis label
ax.set_ylabel(r'$\kappa_{\rm L}$ (W/m/K)',fontsize=19)

# Y-axis limit
ax.set_ylim(0, 3.0)
#plt.xticks(rotation=20)
ax.set_xticks(range(len(categories)))
ax.set_xticklabels(categories, rotation=20, fontsize=19)

# Display plot
plt.tight_layout()
plt.savefig('man_pbte_kappa.pdf', format='pdf',bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# Data for stacked bar chart
categories = ['3ph-QPA', '3ph-BQPA', '3,4ph-QPA', '3,4ph-BQPA']
bottom_values = kappa_mgo_d
top_values = kappa_mgo_od  # Difference to make the total height match the plot

# Colors for each bar (bottom and top)
bottom_colors = ['#d63f27', '#3cb3d8', '#008878', '#8e44ad']  # Added purple
top_colors = ['#f29c9c', '#9ee1f3', '#7ac1ac', '#d2b4de']     # Lighter purple

# Plotting
fig, ax = plt.subplots(figsize=(6, 4.5))  # width x height in inches

# Plot bars
for i in range(len(categories)):
    ax.bar(categories[i], bottom_values[i], color=bottom_colors[i], width=0.6)
    ax.bar(categories[i], top_values[i], bottom=bottom_values[i], color=top_colors[i], width=0.6)

# D. G. Cahill, S.-M. Lee, and T. I. Selinder, Thermal conductivity of κ-Al2O3 and α-Al2O3 wear-resistant 
#coatings, J. Appl. Phys. 83, 5783 (1998).
ax.axhline(y=50.70, color='grey', linestyle='--', linewidth=1)
ax.text(len(categories)-1.25, 57.5, 'Exp.', fontsize=20, va='bottom', ha='right', color='grey')
plt.text(1.75, 70, 'MgO @ 300K', fontsize=20)

# Y-axis label
ax.set_ylabel(r'$\kappa_{\rm L}$ (W/m/K)',fontsize=19)

# Y-axis limit
ax.set_ylim(0, 80.0)
#plt.xticks(rotation=20)
ax.set_xticks(range(len(categories)))
ax.set_xticklabels(categories, rotation=20, fontsize=19)

# Display plot
plt.tight_layout()
plt.savefig('man_mgo_kappa.pdf', format='pdf',bbox_inches='tight')
plt.show()

# %% [markdown]
# # AgCl

# %%
import matplotlib.pyplot as plt
path_work="./Ana-AgCl/"

file1=f"{path_work}/info_spectrum_3ph/BTE.omega"
omega = np.loadtxt(file1)

file1=f"{path_work}/info_spectrum_3ph/lifetime_mat_onsite.txt"
file2=f"{path_work}/info_spectrum_3ph/lifetime_mat.txt"

with open(file1,"r") as file:
    data1 = np.array(json.load(file))
with open(file2,"r") as file:
    data2 = np.array(json.load(file))
    

lifeimte_onsite = np.array([mat.diagonal() for mat in data1]).flatten()
ifeimte_renorm = np.array([mat.diagonal() for mat in data2]).flatten()
print (min(lifeimte_onsite))
print (max(lifeimte_onsite))

# Example data
X = np.array(omega.flatten())/2/pi
Y = lifeimte_onsite
Z = ifeimte_renorm

plt.figure(figsize=(5, 2.5))

# Create scatter plot
plt.scatter(X, Y, color=bluethis, marker='x', s=20, alpha=0.5, label='QPA')
plt.scatter(X, Z, color=redthis, marker='v', s=20, alpha=0.5, label='BQPA')
#plt.legend()

# Set plot range
plt.xlim(0, 1.1*max(X))
#plt.ylim(0.05, 4*max(Y))
plt.ylim(0.04, 10**2)

# Set log scale
#plt.xscale('log')
plt.yscale('log')

# Add Y = 1/X line
X_line = np.linspace(0.001, 1.5*max(X), 400)  # Avoid division by zero by starting from 0.1
Y_line = 1 / X_line  #* 2 * np.pi
plt.plot(X_line, Y_line, color='black', linestyle='--', label='Y=1/X')

# Set aspect ratio
#plt.gca().set_aspect(2, adjustable='box')
plt.tick_params(axis='both', which='major', labelsize=20)
#plt.gca().set_aspect('equal', adjustable='datalim')

plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.size'] = 20
plt.xlabel('Phonon frequency (THz)',fontname='Times New Roman',fontsize=20)
plt.ylabel('Lifetimes (ps)',fontname='Times New Roman',fontsize=20)
plt.xticks(np.arange(0, 7.1, 1))

plt.text(2.5, 10**1, 'AgCl-3ph-300 K', fontsize=20)

#plt.figure(figsize=(5, 1))
plt.savefig('man_agcl_3ph_lifetime.pdf', format='pdf',bbox_inches='tight')
# Show plot
plt.show()
# Out:
# 0.0
# 40.856850201726054

# %%
import matplotlib.pyplot as plt
path_work="./Ana-AgCl/"

file1=f"{path_work}/info_spectrum_3ph/BTE.omega"
omega = np.loadtxt(file1)

file1=f"{path_work}/info_spectrum_4ph/lifetime_mat_onsite.txt"
file2=f"{path_work}/info_spectrum_4ph/lifetime_mat.txt"

with open(file1,"r") as file:
    data1 = np.array(json.load(file))
with open(file2,"r") as file:
    data2 = np.array(json.load(file))
    

lifeimte_onsite = np.array([mat.diagonal() for mat in data1]).flatten()
ifeimte_renorm = np.array([mat.diagonal() for mat in data2]).flatten()
print (min(lifeimte_onsite))
print (max(lifeimte_onsite))

# Example data
X = np.array(omega.flatten())/2/pi
Y = lifeimte_onsite
Z = ifeimte_renorm


plt.figure(figsize=(5, 2.5))
# Create scatter plot
plt.scatter(X, Y, color=bluethis, marker='x', s=20, alpha=0.5, label='QPA')
plt.scatter(X, Z, color=redthis, marker='v', s=20, alpha=0.5, label='BQPA')
#plt.legend()

# Set plot range
plt.xlim(0, 1.1*max(X))
#plt.ylim(0.05, 4*max(Y))
plt.ylim(0.04, 10**2)

# Set log scale
#plt.xscale('log')
plt.yscale('log')

# Add Y = 1/X line
X_line = np.linspace(0.001, 1.5*max(X), 400)  # Avoid division by zero by starting from 0.1
Y_line = 1 / X_line  #* 2 * np.pi
plt.plot(X_line, Y_line, color='black', linestyle='--', label='Y=1/X')

# Set aspect ratio
#plt.gca().set_aspect(2., adjustable='box')
plt.tick_params(axis='both', which='major', labelsize=20)
#plt.gca().set_aspect('equal', adjustable='datalim')

plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.size'] = 20
plt.xlabel('Phonon frequency (THz)',fontname='Times New Roman',fontsize=20)
plt.ylabel('Lifetimes (ps)',fontname='Times New Roman',fontsize=20)
plt.xticks(np.arange(0, 7.1, 1))

plt.text(2.5, 10**1, 'AgCl-3,4ph-300 K', fontsize=20)

#plt.figure(figsize=(4, 4))
plt.savefig('man_agcl_34ph_lifetime.pdf', format='pdf',bbox_inches='tight')
# Show plot
plt.show()
# Out:
# 0.0
# 39.22577067293925

# %%
import csv

path_work="./Ana-AgCl/"
ikpt = 5
natom=2
file_tmp = f"{path_work}/info_spectrum_3ph/bspec_omega_{ikpt}.dat"
with open(file_tmp, "r") as file:
    reader = csv.reader(file)
    data = list(reader)

# check integration
for imod in range(3*natom):
    X=list(map(float,data[imod*3+1][0].split()))
    Y=list(map(float,data[imod*3+2][0].split()))
    dx = X[2]-X[1]
    
    
import matplotlib.pyplot as plt
plt.figure(figsize=(5, 2.5))

# Define a list of colors
colors = plt.cm.get_cmap('tab20', 3*natom)  # Getting a colormap with 24 distinct colors

# Create line plots and add vertical lines
for imod in range(3*natom):
    vertical_line_position = float(data[imod*3+0][0])/2/np.pi
    X = list(map(float, data[imod*3+1][0].split()))
    Y = list(map(float, data[imod*3+2][0].split()))
    
    color = colors(imod)
    
    # Plot the data with specified color
    plt.plot(np.array(X)/2/np.pi, Y, color=color, linestyle='-', linewidth=2, alpha=0.75)
    
    # Add vertical line at the specified position with the same color
    plt.axvline(x=vertical_line_position, color=color, linestyle='--', linewidth=1)

# Set plot range
plt.xlim(0, 7)
plt.ylim(0, 1.0)
#plt.xscale('log')

# Set aspect ratio
#plt.gca().set_aspect(15, adjustable='box')
#plt.gca().set_aspect(100, adjustable='box')
plt.tick_params(axis='both', which='major', labelsize=20)

plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.size'] = 20
plt.xlabel('Phonon frequency (THz)',fontname='Times New Roman',fontsize=20)
plt.ylabel('Spectral density',fontname='Times New Roman',fontsize=20)
plt.xticks(np.arange(0, 7.1, 1))

plt.text(2.5, 0.6, 'AgCl-3ph-300 K', fontsize=20)

plt.savefig(f'man_agcl_3ph_ikpt{ikpt}.pdf', format='pdf',bbox_inches='tight')

plt.show()
# Out:
# /var/folders/m0/zxhk9c3s0dl9_n2kfc6xqkn80000gn/T/ipykernel_48003/2440491871.py:22: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = plt.cm.get_cmap('tab20', 3*natom)  # Getting a colormap with 24 distinct colors

# %%
import csv

path_work="./Ana-AgCl/"
ikpt = 5
natom=2
file_tmp = f"{path_work}/info_spectrum_4ph/bspec_omega_{ikpt}.dat"
with open(file_tmp, "r") as file:
    reader = csv.reader(file)
    data = list(reader)

# check integration
for imod in range(3*natom):
    X=list(map(float,data[imod*3+1][0].split()))
    Y=list(map(float,data[imod*3+2][0].split()))
    dx = X[2]-X[1]
    
    
import matplotlib.pyplot as plt
plt.figure(figsize=(5, 2.5))

# Define a list of colors
colors = plt.cm.get_cmap('tab20', 3*natom)  # Getting a colormap with 24 distinct colors

# Create line plots and add vertical lines
for imod in range(3*natom):
    vertical_line_position = float(data[imod*3+0][0])/2/np.pi
    X = list(map(float, data[imod*3+1][0].split()))
    Y = list(map(float, data[imod*3+2][0].split()))
    
    color = colors(imod)
    
    # Plot the data with specified color
    plt.plot(np.array(X)/2/np.pi, Y, color=color, linestyle='-', linewidth=2, alpha=0.75)
    
    # Add vertical line at the specified position with the same color
    plt.axvline(x=vertical_line_position, color=color, linestyle='--', linewidth=1)

# Set plot range
plt.xlim(0, 7)
plt.ylim(0, 1.0)
#plt.xscale('log')

# Set aspect ratio
#plt.gca().set_aspect(15, adjustable='box')
#plt.gca().set_aspect(100, adjustable='box')
plt.tick_params(axis='both', which='major', labelsize=20)

plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.size'] = 20
plt.xlabel('Phonon frequency (THz)',fontname='Times New Roman',fontsize=20)
plt.ylabel('Spectral density',fontname='Times New Roman',fontsize=20)
plt.xticks(np.arange(0, 7.1, 1))

plt.text(2.5, 0.6, 'AgCl-3,4ph-300 K', fontsize=20)

plt.savefig(f'man_agcl_34ph_ikpt{ikpt}.pdf', format='pdf',bbox_inches='tight')

plt.show()
# Out:
# /var/folders/m0/zxhk9c3s0dl9_n2kfc6xqkn80000gn/T/ipykernel_48003/2428931888.py:22: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = plt.cm.get_cmap('tab20', 3*natom)  # Getting a colormap with 24 distinct colors

# %% [markdown]
# # PbTe

# %%
import matplotlib.pyplot as plt
path_work="./Ana-PbTe/"

file1=f"{path_work}/info_spectrum_3ph/BTE.omega"
omega = np.loadtxt(file1)

file1=f"{path_work}/info_spectrum_3ph/lifetime_mat_onsite.txt"
file2=f"{path_work}/info_spectrum_3ph/lifetime_mat.txt"

with open(file1,"r") as file:
    data1 = np.array(json.load(file))
with open(file2,"r") as file:
    data2 = np.array(json.load(file))
    

lifeimte_onsite = np.array([mat.diagonal() for mat in data1]).flatten()
ifeimte_renorm = np.array([mat.diagonal() for mat in data2]).flatten()
print (min(lifeimte_onsite))
print (max(lifeimte_onsite))

# Example data
X = np.array(omega.flatten())/2/pi
Y = lifeimte_onsite
Z = ifeimte_renorm

plt.figure(figsize=(5, 2.5))

# Create scatter plot
plt.scatter(X, Y, color=bluethis, marker='x', s=10, alpha=0.5)
plt.scatter(X, Z, color=redthis, marker='v', s=10, alpha=0.5)

# Set plot range
plt.xlim(0, 1.1*max(X))
plt.ylim(0.1, 10**3)

# Set log scale
#plt.xscale('log')
plt.yscale('log')

# Add Y = 1/X line
X_line = np.linspace(0.001, 1.5*max(X), 400)  # Avoid division by zero by starting from 0.1
Y_line = 1 / X_line  #* 2 * np.pi
plt.plot(X_line, Y_line, color='black', linestyle='--', label='Y=1/X')

# Set aspect ratio
#plt.gca().set_aspect(1, adjustable='box')
plt.tick_params(axis='both', which='major', labelsize=20)
#plt.gca().set_aspect('equal', adjustable='datalim')

plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.size'] = 20
plt.xlabel('Phonon frequency (THz)',fontname='Times New Roman',fontsize=20)
plt.ylabel('Lifetimes (ps)',fontname='Times New Roman',fontsize=20)
plt.xticks(np.arange(0, 4.1, 1))

plt.text(1.5, 0.5*10**2, 'PbTe-3ph-300 K', fontsize=20)

#plt.figure(figsize=(4, 4))
plt.savefig('man_pbte_3ph_lifetime.pdf', format='pdf',bbox_inches='tight')
# Show plot
plt.show()
# Out:
# 0.0
# 666.5828527802432

# %%
import matplotlib.pyplot as plt
path_work="./Ana-PbTe/"

file1=f"{path_work}/info_spectrum_3ph/BTE.omega"
omega = np.loadtxt(file1)

file1=f"{path_work}/info_spectrum_4ph/lifetime_mat_onsite.txt"
file2=f"{path_work}/info_spectrum_4ph/lifetime_mat.txt"

with open(file1,"r") as file:
    data1 = np.array(json.load(file))
with open(file2,"r") as file:
    data2 = np.array(json.load(file))
    

lifeimte_onsite = np.array([mat.diagonal() for mat in data1]).flatten()
ifeimte_renorm = np.array([mat.diagonal() for mat in data2]).flatten()
print (min(lifeimte_onsite))
print (max(lifeimte_onsite))

# Example data
X = np.array(omega.flatten())/2/pi
Y = lifeimte_onsite
Z = ifeimte_renorm

plt.figure(figsize=(5, 2.5))

# Create scatter plot
plt.scatter(X, Y, color=bluethis, marker='x', s=10, alpha=0.5)
plt.scatter(X, Z, color=redthis, marker='v', s=10, alpha=0.5)

# Set plot range
plt.xlim(0, 1.1*max(X))
plt.ylim(0.1, 10**3)

# Set log scale
#plt.xscale('log')
plt.yscale('log')

# Add Y = 1/X line
X_line = np.linspace(0.001, 1.5*max(X), 400)  # Avoid division by zero by starting from 0.1
Y_line = 1 / X_line  #* 2 * np.pi
plt.plot(X_line, Y_line, color='black', linestyle='--', label='Y=1/X')

# Set aspect ratio
#plt.gca().set_aspect(1, adjustable='box')
plt.tick_params(axis='both', which='major', labelsize=20)
#plt.gca().set_aspect('equal', adjustable='datalim')

plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.size'] = 20
plt.xlabel('Phonon frequency (THz)',fontname='Times New Roman',fontsize=20)
plt.ylabel('Lifetimes (ps)',fontname='Times New Roman',fontsize=20)
plt.xticks(np.arange(0, 4.1, 1))

plt.text(1.5, 0.5*10**2, 'PbTe-3,4ph-300 K', fontsize=20)

#plt.figure(figsize=(4, 4))
plt.savefig('man_pbte_34ph_lifetime.pdf', format='pdf',bbox_inches='tight')
# Show plot
plt.show()
# Out:
# 0.0
# 577.5270720754227

# %%
import csv

path_work="./Ana-PbTe/"
ikpt = 5
natom=2
file_tmp = f"{path_work}/info_spectrum_3ph/bspec_omega_{ikpt}.dat"
with open(file_tmp, "r") as file:
    reader = csv.reader(file)
    data = list(reader)

# check integration
for imod in range(3*natom):
    X=list(map(float,data[imod*3+1][0].split()))
    Y=list(map(float,data[imod*3+2][0].split()))
    dx = X[2]-X[1]
    
    
import matplotlib.pyplot as plt
plt.figure(figsize=(5, 2.5))

# Define a list of colors
colors = plt.cm.get_cmap('tab20', 3*natom)  # Getting a colormap with 24 distinct colors

# Create line plots and add vertical lines
for imod in range(3*natom):
    vertical_line_position = float(data[imod*3+0][0])/2/np.pi
    X = list(map(float, data[imod*3+1][0].split()))
    Y = list(map(float, data[imod*3+2][0].split()))
    
    color = colors(imod)
    
    # Plot the data with specified color
    plt.plot(np.array(X)/2/np.pi, Y, color=color, linestyle='-', linewidth=2, alpha=0.75)
    
    # Add vertical line at the specified position with the same color
    plt.axvline(x=vertical_line_position, color=color, linestyle='--', linewidth=1)

# Set plot range
plt.xlim(0, 7)
plt.ylim(0, 1.0)
#plt.xscale('log')

# Set aspect ratio
#plt.gca().set_aspect(15, adjustable='box')
#plt.gca().set_aspect(100, adjustable='box')
plt.tick_params(axis='both', which='major', labelsize=20)

plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.size'] = 20
plt.xlabel('Phonon frequency (THz)',fontname='Times New Roman',fontsize=20)
plt.ylabel('Spectral density',fontname='Times New Roman',fontsize=20)
plt.xticks(np.arange(0, 7.1, 1))

plt.text(2.7, 0.6, 'PbTe-3ph-300 K', fontsize=20)

plt.savefig(f'man_pbte_3ph_ikpt{ikpt}.pdf', format='pdf',bbox_inches='tight')

plt.show()
# Out:
# /var/folders/m0/zxhk9c3s0dl9_n2kfc6xqkn80000gn/T/ipykernel_48003/341134905.py:22: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = plt.cm.get_cmap('tab20', 3*natom)  # Getting a colormap with 24 distinct colors

# %%
import csv

path_work="./Ana-PbTe/"
ikpt = 5
natom=2
file_tmp = f"{path_work}/info_spectrum_4ph/bspec_omega_{ikpt}.dat"
with open(file_tmp, "r") as file:
    reader = csv.reader(file)
    data = list(reader)

# check integration
for imod in range(3*natom):
    X=list(map(float,data[imod*3+1][0].split()))
    Y=list(map(float,data[imod*3+2][0].split()))
    dx = X[2]-X[1]
    
    
import matplotlib.pyplot as plt
plt.figure(figsize=(5, 2.5))

# Define a list of colors
colors = plt.cm.get_cmap('tab20', 3*natom)  # Getting a colormap with 24 distinct colors

# Create line plots and add vertical lines
for imod in range(3*natom):
    vertical_line_position = float(data[imod*3+0][0])/2/np.pi
    X = list(map(float, data[imod*3+1][0].split()))
    Y = list(map(float, data[imod*3+2][0].split()))
    
    color = colors(imod)
    
    # Plot the data with specified color
    plt.plot(np.array(X)/2/np.pi, Y, color=color, linestyle='-', linewidth=2, alpha=0.75)
    
    # Add vertical line at the specified position with the same color
    plt.axvline(x=vertical_line_position, color=color, linestyle='--', linewidth=1)

# Set plot range
plt.xlim(0, 7)
plt.ylim(0, 1.0)
#plt.xscale('log')

# Set aspect ratio
#plt.gca().set_aspect(15, adjustable='box')
#plt.gca().set_aspect(100, adjustable='box')
plt.tick_params(axis='both', which='major', labelsize=20)

plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.size'] = 20
plt.xlabel('Phonon frequency (THz)',fontname='Times New Roman',fontsize=20)
plt.ylabel('Spectral density',fontname='Times New Roman',fontsize=20)
plt.xticks(np.arange(0, 7.1, 1))

plt.text(2.7, 0.6, 'PbTe-3,4ph-300 K', fontsize=20)

plt.savefig(f'man_pbte_34ph_ikpt{ikpt}.pdf', format='pdf',bbox_inches='tight')

plt.show()
# Out:
# /var/folders/m0/zxhk9c3s0dl9_n2kfc6xqkn80000gn/T/ipykernel_48003/2399576372.py:22: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = plt.cm.get_cmap('tab20', 3*natom)  # Getting a colormap with 24 distinct colors

# %% [markdown]
# # MgO

# %%
import matplotlib.pyplot as plt
path_work="./Ana-MgO/"

file1=f"{path_work}/info_spectrum_3ph/BTE.omega"
omega = np.loadtxt(file1)

file1=f"{path_work}/info_spectrum_3ph/lifetime_mat_onsite.txt"
file2=f"{path_work}/info_spectrum_3ph/lifetime_mat.txt"

with open(file1,"r") as file:
    data1 = np.array(json.load(file))
with open(file2,"r") as file:
    data2 = np.array(json.load(file))
    

lifeimte_onsite = np.array([mat.diagonal() for mat in data1]).flatten()
ifeimte_renorm = np.array([mat.diagonal() for mat in data2]).flatten()
print (min(lifeimte_onsite))
print (max(lifeimte_onsite))

# Example data
X = np.array(omega.flatten())/2/pi
Y = lifeimte_onsite
Z = ifeimte_renorm

plt.figure(figsize=(5, 2.5))

# Create scatter plot
#plt.scatter(X, Y, color=bluethis, marker='x', s=10, alpha=0.5)
#plt.scatter(X, Z, color=redthis, marker='v', s=10, alpha=0.5)
plt.scatter(X, Y, color=bluethis, marker='x', s=20, alpha=0.5, label='QPA')
plt.scatter(X, Z, color=redthis, marker='v', s=20, alpha=0.5, label='BQPA')
plt.legend(loc='center left', bbox_to_anchor=(0.55, 0.55), handletextpad=0.1)
plt.legend(fontsize=16,handletextpad=0.3)

# Set plot range
plt.xlim(0, 1.1*max(X))
plt.ylim(0.1, 10**3)

# Set log scale
#plt.xscale('log')
plt.yscale('log')

# Add Y = 1/X line
X_line = np.linspace(0.001, 1.5*max(X), 400)  # Avoid division by zero by starting from 0.1
Y_line = 1 / X_line  #* 2 * np.pi
plt.plot(X_line, Y_line, color='black', linestyle='--', label='Y=1/X')

# Set aspect ratio
#plt.gca().set_aspect(5.5, adjustable='box')
plt.tick_params(axis='both', which='major', labelsize=20)
#plt.gca().set_aspect('equal', adjustable='datalim')

plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.size'] = 20
plt.xlabel('Phonon frequency (THz)',fontname='Times New Roman',fontsize=20)
plt.ylabel('Lifetimes (ps)',fontname='Times New Roman',fontsize=20)
plt.xticks(np.arange(0, 21, 5))

plt.text(8, 10**2, 'MgO-3ph-300 K', fontsize=20)

#plt.figure(figsize=(4, 4))
plt.savefig('man_mgo_3ph_lifetime.pdf', format='pdf',bbox_inches='tight')
# Show plot
plt.show()
# Out:
# 0.0
# 356.16892428553496

# %%
import matplotlib.pyplot as plt
path_work="./Ana-MgO/"

file1=f"{path_work}/info_spectrum_3ph/BTE.omega"
omega = np.loadtxt(file1)

file1=f"{path_work}/info_spectrum_4ph/lifetime_mat_onsite.txt"
file2=f"{path_work}/info_spectrum_4ph/lifetime_mat.txt"

with open(file1,"r") as file:
    data1 = np.array(json.load(file))
with open(file2,"r") as file:
    data2 = np.array(json.load(file))
    

lifeimte_onsite = np.array([mat.diagonal() for mat in data1]).flatten()
ifeimte_renorm = np.array([mat.diagonal() for mat in data2]).flatten()
print (min(lifeimte_onsite))
print (max(lifeimte_onsite))

# Example data
X = np.array(omega.flatten())/2/pi
Y = lifeimte_onsite
Z = ifeimte_renorm

plt.figure(figsize=(5, 2.5))

# Create scatter plot
plt.scatter(X, Y, color=bluethis, marker='x', s=10, alpha=0.5)
plt.scatter(X, Z, color=redthis, marker='v', s=10, alpha=0.5)

# Set plot range
plt.xlim(0, 1.1*max(X))
plt.ylim(0.1, 10**3)

# Set log scale
#plt.xscale('log')
plt.yscale('log')

# Add Y = 1/X line
X_line = np.linspace(0.001, 1.5*max(X), 400)  # Avoid division by zero by starting from 0.1
Y_line = 1 / X_line  #* 2 * np.pi
plt.plot(X_line, Y_line, color='black', linestyle='--', label='Y=1/X')

# Set aspect ratio
#plt.gca().set_aspect(5.5, adjustable='box')
plt.tick_params(axis='both', which='major', labelsize=20)
#plt.gca().set_aspect('equal', adjustable='datalim')

plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.size'] = 20
plt.xlabel('Phonon frequency (THz)',fontname='Times New Roman',fontsize=20)
plt.ylabel('Lifetimes (ps)',fontname='Times New Roman',fontsize=20)
plt.xticks(np.arange(0, 21, 5))

plt.text(8, 10**2, 'MgO-3,4ph-300 K', fontsize=20)

#plt.figure(figsize=(4, 4))
plt.savefig('man_mgo_34ph_lifetime.pdf', format='pdf',bbox_inches='tight')
# Show plot
plt.show()
# Out:
# 0.0
# 354.14501607091694

# %%
import csv

path_work="./Ana-MgO/"
ikpt = 5
natom=2
file_tmp = f"{path_work}/info_spectrum_3ph/bspec_omega_{ikpt}.dat"
with open(file_tmp, "r") as file:
    reader = csv.reader(file)
    data = list(reader)

# check integration
for imod in range(3*natom):
    X=list(map(float,data[imod*3+1][0].split()))
    Y=list(map(float,data[imod*3+2][0].split()))
    dx = X[2]-X[1]
    
    
import matplotlib.pyplot as plt
plt.figure(figsize=(5, 2.5))

# Define a list of colors
colors = plt.cm.get_cmap('tab20', 3*natom)  # Getting a colormap with 24 distinct colors

# Create line plots and add vertical lines
for imod in range(3*natom):
    vertical_line_position = float(data[imod*3+0][0])/2/np.pi
    X = list(map(float, data[imod*3+1][0].split()))
    Y = list(map(float, data[imod*3+2][0].split()))
    
    color = colors(imod)
    
    # Plot the data with specified color
    plt.plot(np.array(X)/2/np.pi, Y, color=color, linestyle='-', linewidth=2, alpha=0.75)
    
    # Add vertical line at the specified position with the same color
    plt.axvline(x=vertical_line_position, color=color, linestyle='--', linewidth=1)

# Set plot range
plt.xlim(0, 25)
plt.ylim(0, 2)
#plt.xscale('log')

# Set aspect ratio
#plt.gca().set_aspect(50, adjustable='box')
plt.tick_params(axis='both', which='major', labelsize=20)

plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.size'] = 20
plt.xlabel('Phonon frequency (THz)',fontname='Times New Roman',fontsize=20)
plt.ylabel('Spectral density',fontname='Times New Roman',fontsize=20)
plt.xticks(np.arange(0, 30, 5))

plt.text(12, 1.2, 'MgO-3ph-300 K', fontsize=20)

plt.savefig(f'man_mgo_3ph_ikpt{ikpt}.pdf', format='pdf',bbox_inches='tight')

plt.show()
# Out:
# /var/folders/m0/zxhk9c3s0dl9_n2kfc6xqkn80000gn/T/ipykernel_48003/3882840518.py:22: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = plt.cm.get_cmap('tab20', 3*natom)  # Getting a colormap with 24 distinct colors

# %%
import csv

path_work="./Ana-MgO/"
ikpt = 5
natom=2
file_tmp = f"{path_work}/info_spectrum_4ph/bspec_omega_{ikpt}.dat"
with open(file_tmp, "r") as file:
    reader = csv.reader(file)
    data = list(reader)

# check integration
for imod in range(3*natom):
    X=list(map(float,data[imod*3+1][0].split()))
    Y=list(map(float,data[imod*3+2][0].split()))
    dx = X[2]-X[1]
    
    
import matplotlib.pyplot as plt

plt.figure(figsize=(5, 2.5))

# Define a list of colors
colors = plt.cm.get_cmap('tab20', 3*natom)  # Getting a colormap with 24 distinct colors

# Create line plots and add vertical lines
for imod in range(3*natom):
    vertical_line_position = float(data[imod*3+0][0])/2/np.pi
    X = list(map(float, data[imod*3+1][0].split()))
    Y = list(map(float, data[imod*3+2][0].split()))
    
    color = colors(imod)
    
    # Plot the data with specified color
    plt.plot(np.array(X)/2/np.pi, Y, color=color, linestyle='-', linewidth=2, alpha=0.75)
    
    # Add vertical line at the specified position with the same color
    plt.axvline(x=vertical_line_position, color=color, linestyle='--', linewidth=1)

# Set plot range
plt.xlim(0, 25)
plt.ylim(0, 2)
#plt.xscale('log')

# Set aspect ratio
#plt.gca().set_aspect(50, adjustable='box')
plt.tick_params(axis='both', which='major', labelsize=20)

plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.size'] = 20
plt.xlabel('Phonon frequency (THz)',fontname='Times New Roman',fontsize=20)
plt.ylabel('Spectral density',fontname='Times New Roman',fontsize=20)
plt.xticks(np.arange(0, 30, 5))

plt.text(11, 1.2, 'MgO-3,4ph-300 K', fontsize=20)

plt.savefig(f'man_mgo_34ph_ikpt{ikpt}.pdf', format='pdf',bbox_inches='tight')

plt.show()
# Out:
# /var/folders/m0/zxhk9c3s0dl9_n2kfc6xqkn80000gn/T/ipykernel_48003/771888351.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = plt.cm.get_cmap('tab20', 3*natom)  # Getting a colormap with 24 distinct colors
